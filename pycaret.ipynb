# %%
from Bio import SeqIO, motifs
from Bio.Seq import Seq
import pandas as pd
import numpy as np
import csv
from Bio.SeqRecord import SeqRecord
import torch
import json
from transformers import AutoTokenizer, AutoModel
from sklearn.preprocessing import StandardScaler

# %%
training_data = pd.read_csv("df_train_feature_pb.csv", index_col=0)
testing_data = pd.read_csv("df_test_feature_pb.csv", index_col=0)

# %%
testing_data.index = pd.RangeIndex(start=2518, stop=3148)

# %%
training_data
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.208095  0.220136 -0.197749 -0.210119 -0.225618 -0.220520 -0.218668
# 1    -0.209904  0.222025 -0.199485 -0.211941 -0.227543 -0.222412 -0.220548
# 2    -0.210550  0.222705 -0.200102 -0.212592 -0.228237 -0.223093 -0.221223
# 3    -0.207671  0.219691 -0.197343 -0.209691 -0.225164 -0.220075 -0.218226
# 4    -0.208217  0.220262 -0.197866 -0.210241 -0.225746 -0.220647 -0.218794
# ...        ...       ...       ...       ...       ...       ...       ...
# 2513 -0.207851  0.219878 -0.197517 -0.209872 -0.225354 -0.220262 -0.218412
# 2514 -0.209156  0.221244 -0.198767 -0.211187 -0.226747 -0.221630 -0.219771
# 2515 -0.207422  0.219431 -0.197104 -0.209440 -0.224898 -0.219814 -0.217967
# 2516 -0.209384  0.221483 -0.198985 -0.211417 -0.226991 -0.221869 -0.220009
# 2517 -0.209909  0.222034 -0.199486 -0.211946 -0.227554 -0.222421 -0.220557
#
# ...

# %%
from pycaret.classification import *

s=setup(data=training_data, target='Label',test_data=testing_data)
# Out:
# <style type="text/css">
# #T_c9a62_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c9a62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9a62_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c9a62_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9a62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9a62_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c9a62_row0_col1" class="data row0 col1" >2522</td>
#     </tr>
#     <tr>
#       <th id="T_c9a62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9a62_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c9a62_row1_col1" class="data row1 col1" >Label</td>
#     </tr>
#     <tr>
#       <th id="T_c9a62_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         18:06:41
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_38070 th {
#   text-align: left;
# }
# ...

# %%
rf_model = create_model('ada')
# Out:
# <style type="text/css">
# #T_efbf3_row10_col0, #T_efbf3_row10_col1, #T_efbf3_row10_col2, #T_efbf3_row10_col3, #T_efbf3_row10_col4, #T_efbf3_row10_col5, #T_efbf3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_efbf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efbf3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_efbf3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_efbf3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_efbf3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_efbf3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_efbf3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_efbf3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(rf_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
